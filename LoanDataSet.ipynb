# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
lp_file = pd.read_csv("loan_prediction.csv")

# %%
lp_file
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lp_file.shape
# Out:
# (614, 13)

# %%
lp_file.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
lp_file.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
lp_file.sample(5)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 221  LP001743    Male     Yes          2      Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 372  LP002201    Male     Yes          2      Graduate           Yes
# 400  LP002288    Male     Yes          2  Not Graduate            No
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 221             4009             1717.0       116.0             360.0
# 561            19484                0.0       600.0             360.0
# 372             9323             7873.0       380.0             300.0
# 400             2889                0.0        45.0             180.0
# 216              150             1800.0       135.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 221             1.0     Semiurban           Y
# ...

# %%
lp_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
lp_file.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
lp_file.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
lp_file.dropna(axis=0,inplace=True)

# %%
lp_file.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
lp_file.loc[:,['Loan_ID', 'Education']]
# Out:
#       Loan_ID     Education
# 1    LP001003      Graduate
# 2    LP001005      Graduate
# 3    LP001006  Not Graduate
# 4    LP001008      Graduate
# 5    LP001011      Graduate
# ..        ...           ...
# 609  LP002978      Graduate
# 610  LP002979      Graduate
# 611  LP002983      Graduate
# 612  LP002984      Graduate
# 613  LP002990      Graduate
#
# [480 rows x 2 columns]

# %%
lp_file.loc[20:26,['Loan_ID', 'Education']]
# Out:
#      Loan_ID     Education
# 20  LP001043  Not Graduate
# 21  LP001046      Graduate
# 22  LP001047  Not Graduate
# 25  LP001066      Graduate
# 26  LP001068      Graduate

# %%
lp_file.iloc[1:10,2:11]
# Out:
#    Married Dependents     Education Self_Employed  ApplicantIncome  \
# 2      Yes          0      Graduate           Yes             3000
# 3      Yes          0  Not Graduate            No             2583
# 4       No          0      Graduate            No             6000
# 5      Yes          2      Graduate           Yes             5417
# 6      Yes          0  Not Graduate            No             2333
# 7      Yes         3+      Graduate            No             3036
# 8      Yes          2      Graduate            No             4006
# 9      Yes          1      Graduate            No            12841
# 10     Yes          2      Graduate            No             3200
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 2                 0.0        66.0             360.0             1.0
# 3              2358.0       120.0             360.0             1.0
# 4                 0.0       141.0             360.0             1.0
# ...

# %%
lp_file['LoanAmount'].min()
# Out:
# 9.0

# %%
lp_file['LoanAmount'].max()
# Out:
# 600.0

# %%
lp_file['LoanAmount'].mean()
# Out:
# 144.73541666666668

# %%
lp_file['LoanAmount'].median()
# Out:
# 128.0

# %%
lp_file['LoanAmount'].mode()
# Out:
# 0    100.0
# 1    110.0
# 2    120.0
# Name: LoanAmount, dtype: float64

# %%
lp_file['LoanAmount'].count()
# Out:
# 480

# %%
lp_file['LoanAmount'].unique()
# Out:
# array([128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70., 200.,
#        114.,  17., 125.,  76., 133., 104., 315., 116., 191., 122., 110.,
#         35.,  74., 106., 320., 144., 184.,  80.,  47., 134.,  44., 100.,
#        112., 286.,  97.,  96., 135., 180.,  99., 165., 258., 126., 312.,
#        136., 172.,  81., 187., 113., 176., 111., 167.,  50., 210., 175.,
#        131., 188.,  25., 137., 115., 151., 225., 216.,  94., 185., 154.,
#        259., 194., 160., 102., 290.,  84.,  88., 242., 129.,  30., 118.,
#        152., 244., 600., 255.,  98., 275., 121.,  75.,  63.,  87., 101.,
#        495.,  73., 260., 108.,  48., 164., 170.,  83.,  90., 166., 124.,
#         55.,  59., 127., 214., 240., 130.,  60., 280., 140., 155., 123.,
#        201., 138., 279., 192., 304., 150., 207., 436.,  78.,  54.,  89.,
#        139.,  93., 132., 480.,  56., 300., 376.,  67., 117.,  71., 173.,
#         46., 228., 308., 105., 236., 570., 380., 296., 156., 109., 103.,
# ...

# %%
lp_file['LoanAmount'].nunique()
# Out:
# 186

# %%
lp_file['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
lp_file['Gender'].nunique()
# Out:
# 2

# %%
lp_file['Gender'].value_counts()
# Out:
# Gender
# Male      394
# Female     86
# Name: count, dtype: int64

# %%
lp_file['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 120.0    13
# 100.0    13
# 110.0    13
# 187.0    12
# 128.0     9
#          ..
# 280.0     1
# 240.0     1
# 214.0     1
# 59.0      1
# 253.0     1
# Name: count, Length: 186, dtype: int64

# %%
lp_file.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
lp_file.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        480    480     480        480       480           480
# unique       480      2       2          4         2             2
# top     LP001003   Male     Yes          0  Graduate            No
# freq           1    394     311        274       383           414
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        480.000000         480.000000  480.000000        480.000000
# ...

# %%
lp_file[(lp_file['LoanAmount'] >=300) & (lp_file['Education']=='Graduate')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 21   LP001046    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 67   LP001233    Male     Yes          1  Graduate            No
# 155  LP001536    Male     Yes         3+  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 258  LP001859    Male     Yes          0  Graduate            No
# 278  LP001907    Male     Yes          0  Graduate            No
# 308  LP001996    Male      No          0  Graduate            No
# 324  LP002065    Male     Yes         3+  Graduate            No
# 325  LP002067    Male     Yes          1  Graduate           Yes
# 351  LP002140    Male      No          0  Graduate            No
# 369  LP002191    Male     Yes          0  Graduate            No
# ...

# %%
lp_file.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
lp_file.rename(columns={'Education':'EDUCATION'} ,inplace=True)
lp_file
# Out:
#       Loan_ID  Gender Married Dependents     EDUCATION Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lp_file.drop('Married',axis=1)
# Out:
#       Loan_ID  Gender Dependents     EDUCATION Self_Employed  ApplicantIncome  \
# 1    LP001003    Male          1      Graduate            No             4583
# 2    LP001005    Male          0      Graduate           Yes             3000
# 3    LP001006    Male          0  Not Graduate            No             2583
# 4    LP001008    Male          0      Graduate            No             6000
# 5    LP001011    Male          2      Graduate           Yes             5417
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978  Female          0      Graduate            No             2900
# 610  LP002979    Male         3+      Graduate            No             4106
# 611  LP002983    Male          1      Graduate            No             8072
# 612  LP002984    Male          2      Graduate            No             7583
# 613  LP002990  Female          0      Graduate           Yes             4583
#
# ...

# %%
lp_file.drop([3,613,609,4,5],axis=0)
# Out:
#       Loan_ID Gender Married Dependents     EDUCATION Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 7    LP001014   Male     Yes         3+      Graduate            No
# 8    LP001018   Male     Yes          2      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
lp_file.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     EDUCATION Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lp_file.
# Out:
#       Loan_ID  Gender Married Dependents     EDUCATION Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lp_file.to_csv("lp_file_Output.csv")
